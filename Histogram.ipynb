# %%
import matplotlib.pyplot as plt
data_students=[5,15,25,35,45,55]
plt.hist(data_students,bins=[0,10,20,30,40,50,60],weights=[20,10,45,33,6,8],edgecolor='red')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
height=np.arange(150,200,2)
bins=[150,165,175,190,200]
plt.hist(height,rwidth=.8,bins=bins,color='green')
# Out:
# (array([8., 5., 7., 5.]),
#  array([150, 165, 175, 190, 200]),
#  <BarContainer object of 4 artists>)
